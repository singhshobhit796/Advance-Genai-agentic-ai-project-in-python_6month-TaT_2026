# %% [markdown]
# # variable declartion in python (variable = object = identifier)
# -variable(object) = value (datatypes)

# %%
nit = 1030
nit
# Out:
# 1030

# %%
1030 = nit
# Out:
#   Cell In[2], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#
1nit = 10
1nit
# Out:
#   Cell In[3], line 2
#     1nit = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 10 
nit1
# Out:
# 10

# %%
nit = 20 
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit = 20
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit

# %%
nit@ = 8 
nit@
# Out:
#   Cell In[6], line 1
#     nit@ = 8
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 32 
nit_
# Out:
# 32

# %%
nit$ = 6
nit$
# Out:
#   Cell In[8], line 1
#     nit$ = 6
#        ^
# SyntaxError: invalid syntax

# %%
_nit = 5
_nit
# Out:
# 5

# %%
a = 35
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 a = 35
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
_nit
# Out:
# 5

# %%
_
# Out:
# '{"dataframes": [], "user": "Admin"}'

# %%
_nit
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for = 45
for
# Out:
#   Cell In[17], line 1
#     for = 45
#         ^
# SyntaxError: invalid syntax

# %%
For = 50 
For
# Out:
# 50

# %%
if = 67
if
# Out:
#   Cell In[19], line 1
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
If = 67
If
# Out:
# 67

# %%
else = 7
# Out:
#   Cell In[21], line 1
#     else = 7
#     ^
# SyntaxError: invalid syntax

# %%
true = 7
true
# Out:
# 7

# %%
a = true
a
# Out:
# 7

# %% [markdown]
# # python variable we are completed

# %% [markdown]
# # 10th -- python datatype

# %%
i = 5
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140715589280808

# %%
f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
gold_price = 14800.78
gold_price
# Out:
# 14800.78

# %%
type(gold_price)
# Out:
# float

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10+5)
print(10-5)
print(10*5)
# Out:
# 15
# 5
# 50

# %%
f1 = 2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e3
f2
# Out:
# 3500.0

# %%
f3 = 3.5e3
f3
# Out:
# 3500.0

# %% [markdown]
# # boolean value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True    #float division
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # complex

# %%
c = 10 + 20j   # 10 - real part & 20 imaginary part where j = squre root of -1 
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %% [markdown]
# # integer, float, complex, bool

# %% [markdown]
# # 11

# %%
i = 4
i
# Out:
# 4

# %%
type(i)
# Out:
# int

# %%
f = 4.5
f
# Out:
# 4.5

# %%
type(f)
# Out:
# float

# %%
b = True
b1 = False
c = b+b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
c = 1 + 2j
c
# Out:
# (1+2j)

# %%
c1 = 3 + 4j

# %%
print(c)
print(c1)
# Out:
# (1+2j)
# (3+4j)

# %%
c + c1
# Out:
# (4+6j)

# %% [markdown]
# # string

# %%
welcome to nareshit & request everyone please subscribe nareshit youtube, instagram
# Out:
#   Cell In[61], line 1
#     welcome to nareshit & request everyone please subscribe nareshit youtube, instagram
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to nareshit & request everyone please subscribe nareshit youtube, instagram'
# Out:
# 'welcome to nareshit & request everyone please subscribe nareshit youtube, instagram'

# %%
"welcome to nareshit & request everyone please subscribe nareshit youtube, instagram"
# Out:
# 'welcome to nareshit & request everyone please subscribe nareshit youtube, instagram'

# %%
'''welcome to nareshit & request everyone please subscribe nareshit youtube, instagram'''
# Out:
# 'welcome to nareshit & request everyone please subscribe nareshit youtube, instagram'

# %%
'welcome to nareshit 
request everyone please
subscribe nareshit youtube, instagram'
# Out:
#   Cell In[65], line 1
#     'welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to nareshit 
request everyone please
subscribe nareshit youtube, instagram"
# Out:
#   Cell In[66], line 1
#     "welcome to nareshit
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to nareshit 
request everyone please
subscribe nareshit youtube, instagram'''
# Out:
# 'welcome to nareshit \nrequest everyone please\nsubscribe nareshit youtube, instagram'

# %%
s = 'python'
s
# Out:
# 'python'

# %%
s1 = 'welcome'
s1
# Out:
# 'welcome'

# %%
s1[3]
# Out:
# 'c'

# %%
s1[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 s1[9]
#
# IndexError: string index out of range

# %%
s1
# Out:
# 'welcome'

# %%
s1[-3]
# Out:
# 'o'

# %%
s1[-5]
# Out:
# 'l'

# %%
s1
# Out:
# 'welcome'

# %%
s1[6]
# Out:
# 'e'

# %%
s1
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[:]
# Out:
# 'welcome'

# %%
s1[1:4] # forward slicing
# Out:
# 'elc'

# %%
s1[3:7]
# Out:
# 'come'

# %%
s2 = 'nareshtechnology'
s2
# Out:
# 'nareshtechnology'

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
len(s2)
# Out:
# 16

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[3:]
# Out:
# 'eshtechnology'

# %%
s2[9:]
# Out:
# 'hnology'

# %%
s2[0:]
# Out:
# 'nareshtechnology'

# %%
s3 = 'welcometeam'
s3
# Out:
# 'welcometeam'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3[::-1]
# Out:
# 'maetemoclew'

# %%
s3[::1]
# Out:
# 'welcometeam'

# %%
s3[::2]
# Out:
# 'wloeem'

# %%
s3[::3]
# Out:
# 'wcea'

# %%
s3
# Out:
# 'welcometeam'

# %%
s3[::-2]
# Out:
# 'meeolw'

# %% [markdown]
# # python type casting

# %% [markdown]
# - car()--- car function without argument
#
# - asian_cars('tata' , 'toyta')--- car function with 2 argument | type of argument string
#
# - german_cars('audi' , 'bmw' , 'fereri' , 'vw')--- german car with 4 argument
#
# - today in this code i define 3 function ends with () & :

# %% [markdown]
# # we will type cast all other data type to integer

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3, 3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 int(2.3, 3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatype to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('20')
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # allother datatype to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1 + 2j)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %%
vall = 10 
vall
# Out:
# 10

# %%
import sys
sys.getsizeof(vall)
# Out:
# 28

# %%
vall = [20, 30, 40, 50]
vall
# Out:
# [20, 30, 40, 50]

# %%
import sys
sys.getsizeof(vall)
# Out:
# 88

# %%
__init__ # python constructor teach you oops concept

# %% [markdown]
# # 13th

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10 , 20)
# Out:
# (10+20j)

# %%
complex(10 , 20 ,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 complex(10 , 20 ,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3 , 4.5)
# Out:
# (2.3+4.5j)

# %%
complex(23 , 2.3)
# Out:
# (23+2.3j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True , False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10' , '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 complex('10' , '20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10 , '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 complex(10 , '20')
#
# TypeError: complex() second arg can't be a string

# %%
str(100)
# Out:
# '100'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(2 , 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 str(2 , 3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %% [markdown]
# # python operator

# %% [markdown]
# # arithmetic operator

# %%
x1 , y1 = 10 , 5

# %%
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1 #reminder
# Out:
# 0

# %%
2 * 3
# Out:
# 6

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # assignement operator

# %%
x = 2

# %%
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x *= 2
x
# Out:
# 192

# %%
x * = 2
x
# Out:
#   Cell In[160], line 1
#     x * = 2
#         ^
# SyntaxError: invalid syntax

# %%
x //= 2
x
# Out:
# 96

# %% [markdown]
# # unary operator

# %%
n = 7 #negattion
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # relation operator

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
b < a
# Out:
# False

# %%
a = b

# %%
a == b
# Out:
# True

# %%
c = 5
d = 7

# %%
c == d
# Out:
# False

# %%
c = d

# %%
print(c)
print(d)
# Out:
# 7
# 7

# %%
c == d
# Out:
# True

# %%
c != d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 7
# 7

# %%
c > d
# Out:
# False

# %%
c >= d
# Out:
# True

# %%
c < d
# Out:
# False

# %%
c <= d
# Out:
# True

# %% [markdown]
# # logical table

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a < 8 or b > 5
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 4

# %%
a < 8 and b < 2
# Out:
# False

# %%
a>8 or b<2
# Out:
# False

# %%
x = True
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10 + 3 * 2 - 1
# Out:
# 15

# %%
10 + 3 *( 2 - 1 )
# Out:
# 13

# %%
print(10)
print(10 , 20)
print('python')
print(10 , 20 , 'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20
num2=30

add=num1+num2

print(add)
# Out:
# 50

# %%
num1=20
num2=30

add=num1+num2

print( 'The addition of', num1, 'and' , num2, 'is' , add)
# Out:
# The addition of 20 and 30 is 50
